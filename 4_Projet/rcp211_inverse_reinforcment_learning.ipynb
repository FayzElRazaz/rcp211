# %% [markdown]
# # RCP211 - Inverse Reinforcment Learning - Fayz El Razaz

# %%
# pip install gymnasium stable-baselines3 scipy numpy pandas matplotlib

import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import minimize
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from tqdm import tqdm

ENV_ID = "CartPole-v1"
SEED = 42
np.random.seed(SEED)


# ============================================================
# 1. Entraîner un expert PPO avec la vraie reward CartPole
# ============================================================

expert_env = gym.make(ENV_ID)

expert = PPO(
    "MlpPolicy",
    expert_env,
    seed=SEED,
    verbose=1,
)

expert.learn(total_timesteps=10000)

expert_score, expert_std = evaluate_policy(
    expert,
    gym.make(ENV_ID),
    n_eval_episodes=20,
)

print(f"Expert PPO : {expert_score:.2f} ± {expert_std:.2f}")


# ============================================================
# 2. Collecter des trajectoires expert et random
# ============================================================

def collect_trajectories(policy_type, n_episodes=100):
    env = gym.make(ENV_ID)

    trajectories = []

    for ep in range(n_episodes):
        obs, info = env.reset(seed=SEED + ep)

        done = False
        truncated = False

        obs_list = []
        reward_list = []

        while not (done or truncated):
            if policy_type == "expert":
                action, _ = expert.predict(obs, deterministic=True)
                action = int(action)
            elif policy_type == "random":
                action = env.action_space.sample()
            else:
                raise ValueError("policy_type doit être 'expert' ou 'random'")

            next_obs, reward, done, truncated, info = env.step(action)

            obs_list.append(obs)
            reward_list.append(reward)

            obs = next_obs

        trajectories.append({
            "obs": np.array(obs_list, dtype=np.float32),
            "env_return": np.sum(reward_list),
            "length": len(obs_list),
        })

    env.close()
    return trajectories


expert_trajs = collect_trajectories("expert", n_episodes=50)
random_trajs = collect_trajectories("random", n_episodes=50)

print("Longueur moyenne expert :", np.mean([t["length"] for t in expert_trajs]))
print("Longueur moyenne random :", np.mean([t["length"] for t in random_trajs]))


# ============================================================
# 3. Features physiques de CartPole
# ============================================================

def state_features(obs):
    """
    obs = [x, x_dot, theta, theta_dot]

    On construit des pénalités positives.
    Plus elles sont grandes, plus l'état est mauvais.
    """
    x, x_dot, theta, theta_dot = obs

    return np.array([
        x ** 2,
        x_dot ** 2,
        theta ** 2,
        theta_dot ** 2,
    ], dtype=np.float32)


def trajectory_features(traj):
    """
    Somme des features sur toute la trajectoire.
    """
    return np.mean([state_features(obs) for obs in traj["obs"]], axis=0)


expert_features = np.array([trajectory_features(t) for t in expert_trajs])
random_features = np.array([trajectory_features(t) for t in random_trajs])


# ============================================================
# 4. Apprendre les poids de la reward
# ============================================================

def reward_from_features(phi, w):
    """
    Reward paramétrique :

    R(s) = - w . phi(s)

    avec phi(s) = [x², x_dot², theta², theta_dot²]
    """
    return 2-np.dot(phi, w)


def loss(w):
    """
    On veut que les trajectoires expertes aient une reward cumulée
    supérieure aux trajectoires random.

    Comme R = -w.phi, cela revient à donner une pénalité plus faible
    aux trajectoires expertes.
    """
    expert_scores = -expert_features @ w
    random_scores = -random_features @ w

    # Comparaison moyenne expert vs random
    expert_mean = expert_scores.mean()
    random_mean = random_scores.mean()

    margin = 1.0

    ranking_loss = max(0.0, margin - (expert_mean - random_mean))

    # Régularisation pour éviter des poids énormes
    regularization = 0.01 * np.sum(w ** 2)

    return ranking_loss + regularization


initial_w = np.ones(4)

result = minimize(
    loss,
    x0=initial_w,
    bounds=[(0, None)] * 4,
    method="L-BFGS-B",
)

w_learned = result.x

print("\nPoids appris :")
print(f"x²          : {w_learned[0]:.4f}")
print(f"x_dot²      : {w_learned[1]:.4f}")
print(f"theta²      : {w_learned[2]:.4f}")
print(f"theta_dot²  : {w_learned[3]:.4f}")


# ============================================================
# 5. Comparer reward apprise expert vs random
# ============================================================

def learned_return(traj, w):
    return np.mean([
        reward_from_features(state_features(obs), w)
        for obs in traj["obs"]
    ])


expert_learned_returns = np.array([
    learned_return(t, w_learned) for t in expert_trajs
])

random_learned_returns = np.array([
    learned_return(t, w_learned) for t in random_trajs
])

comparison = pd.DataFrame({
    "policy": ["Expert", "Random"],
    "env_return_mean": [
        np.mean([t["env_return"] for t in expert_trajs]),
        np.mean([t["env_return"] for t in random_trajs]),
    ],
    "learned_return_mean": [
        expert_learned_returns.mean(),
        random_learned_returns.mean(),
    ],
    "trajectory_length_mean": [
        np.mean([t["length"] for t in expert_trajs]),
        np.mean([t["length"] for t in random_trajs]),
    ],
})

print("\nComparaison expert vs random :")
print(comparison)


# ============================================================
# 6. Créer un environnement CartPole avec reward apprise
# ============================================================

class LearnedRewardCartPole(gym.Wrapper):
    def __init__(self, env, w):
        super().__init__(env)
        self.w = w

    def step(self, action):
        obs, original_reward, terminated, truncated, info = self.env.step(action)

        phi = state_features(obs)
        learned_reward = 2+ reward_from_features(phi, self.w)

        info["original_reward"] = original_reward
        info["learned_reward"] = learned_reward

        return obs, learned_reward, terminated, truncated, info


learned_env = LearnedRewardCartPole(
    gym.make(ENV_ID),
    w_learned,
)


# ============================================================
# 7. Entraîner un nouvel agent PPO sur la reward apprise
# ============================================================

irl_agent = PPO(
    "MlpPolicy",
    learned_env,
    seed=SEED,
    verbose=1,
)

irl_agent.learn(total_timesteps=10000)


# ============================================================
# 8. Évaluer l'agent IRL sur la vraie reward CartPole
# ============================================================

eval_env = gym.make(ENV_ID)

irl_score, irl_std = evaluate_policy(
    irl_agent,
    eval_env,
    n_eval_episodes=20,
)

random_scores = []

for ep in tqdm(range(20)):
    env = gym.make(ENV_ID)
    obs, info = env.reset(seed=SEED + ep)

    done = False
    truncated = False
    total_reward = 0

    while not (done or truncated):
        action = env.action_space.sample()
        obs, reward, done, truncated, info = env.step(action)
        total_reward += reward

    random_scores.append(total_reward)
    env.close()

print("\n=== Évaluation finale sur la vraie reward CartPole ===")
print(f"Random       : {np.mean(random_scores):.2f} ± {np.std(random_scores):.2f}")
print(f"Expert PPO   : {expert_score:.2f} ± {expert_std:.2f}")
print(f"IRL niveau 1 : {irl_score:.2f} ± {irl_std:.2f}")


# ============================================================
# 9. Visualiser la reward apprise selon l'angle theta
# ============================================================

angles = np.linspace(-0.25, 0.25, 100)

rewards_angle = []

for theta in tqdm(angles):
    obs = np.array([0.0, 0.0, theta, 0.0])
    phi = state_features(obs)
    rewards_angle.append(reward_from_features(phi, w_learned))

plt.figure()
plt.plot(angles, rewards_angle)
plt.xlabel("Angle theta")
plt.ylabel("Reward apprise")
plt.title("Reward apprise en fonction de l'angle du mât")
plt.show()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 739      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 490         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008349771 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00935     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 52.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011799799 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0738      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 31.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.8       |
# |    ep_rew_mean          | 42.8       |
# | time/                   |            |
# |    fps                  | 431        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00894752 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.629     |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.5       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0226    |
# |    value_loss           | 48.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 54.5        |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008610697 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 55.6        |
# -----------------------------------------
# Expert PPO : 383.20 ± 108.31
# Longueur moyenne expert : 404.62
# Longueur moyenne random : 24.24
#
# Poids appris :
# x²          : 0.5795
# x_dot²      : 0.9903
# theta²      : 0.9456
# theta_dot²  : 1.6267
#
# Comparaison expert vs random :
#    policy  env_return_mean  learned_return_mean  trajectory_length_mean
# 0  Expert           404.62              1.45255                  404.62
# 1  Random            24.24              0.45255                   24.24
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 54.6     |
# | time/              |          |
# |    fps             | 665      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | 70.3        |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011872752 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 285         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 663         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.9        |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008594306 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.0206      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 244         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 579         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.6        |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008305794 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.0605      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 271         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 840         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.5         |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0041641663 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.615       |
# |    explained_variance   | 0.0215       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 423          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00972     |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# /home/intifada/Documents/rcp211/.venv/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 100%|██████████| 20/20 [00:00<00:00, 415.90it/s]
# === Évaluation finale sur la vraie reward CartPole ===
# Random       : 30.60 ± 15.10
# Expert PPO   : 383.20 ± 108.31
# IRL niveau 1 : 291.35 ± 91.58
# 100%|██████████| 100/100 [00:00<00:00, 48703.02it/s]

# %% [markdown]
# ## Construction de l'expert et des démonstrations

# %% [markdown]
# ### Librairie

# %%
import os
import numpy as np
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Configuration

# %%
# =========================
# Configuration
# =========================

ENV_NAME = "CartPole-v1"

ROOT_DIR = os.getcwd ()
MODEL_DIR = os.path.join(ROOT_DIR, "models")
DATA_DIR = os.path.join(ROOT_DIR, "data")

EXPERT_MODEL_PATH = os.path.join(MODEL_DIR, "ppo_cartpole_expert")
DEMO_DATA_PATH = os.path.join(DATA_DIR, "expert_demonstrations.npz")

N_TRAINING_STEPS = 100_000
N_DEMO_EPISODES = 50
MIN_EXPERT_SCORE = 450

SEED = 42

# %% [markdown]
# ### Préparation des dossiers

# %%
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(DATA_DIR, exist_ok=True)

# %% [markdown]
# ### Entraintement de notre expert

# %%
# =========================
# 1. Entraînement expert PPO
# =========================

env = gym.make(ENV_NAME)

model = PPO(
    policy="MlpPolicy",
    env=env,
    verbose=1,
    seed=SEED,
)

model.learn(total_timesteps=N_TRAINING_STEPS)

model.save(EXPERT_MODEL_PATH)

mean_reward, std_reward = evaluate_policy(
    model,
    env,
    n_eval_episodes=20,
    deterministic=True,
)

print("\n=== Évaluation de l'expert PPO ===")
print(f"Score moyen : {mean_reward:.2f} ± {std_reward:.2f}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | 22       |
# | time/              |          |
# |    fps             | 610      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008349771 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00935     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 52.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011799799 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0738      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 31.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 42.8       |
# |    ep_rew_mean          | 42.8       |
# | time/                   |            |
# |    fps                  | 397        |
# |    iterations           | 4          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00894752 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.629     |
# |    explained_variance   | 0.252      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.5       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0226    |
# |    value_loss           | 48.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | 54.5        |
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 5           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008610697 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 55.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.2        |
# |    ep_rew_mean          | 70.2        |
# | time/                   |             |
# |    fps                  | 374         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009621577 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 46.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.1        |
# |    ep_rew_mean          | 88.1        |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 7           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007883211 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 48.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 8           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004140755 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00563    |
# |    value_loss           | 58.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 356          |
# |    iterations           | 9            |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0051169014 |
# |    clip_fraction        | 0.0645       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.23         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00975     |
# |    value_loss           | 62.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 144          |
# |    ep_rew_mean          | 144          |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 10           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056203017 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.567       |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.91         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00766     |
# |    value_loss           | 61.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 11          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012802388 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.548      |
# |    explained_variance   | -0.00722    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 26.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 176          |
# |    ep_rew_mean          | 176          |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 12           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0040536784 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 0.549        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.1         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00437     |
# |    value_loss           | 41.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 198          |
# | time/                   |              |
# |    fps                  | 345          |
# |    iterations           | 13           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0032335282 |
# |    clip_fraction        | 0.0499       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0927       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 5.89         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 216         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 14          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002171695 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.499      |
# |    explained_variance   | 0.087       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.338       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00207     |
# |    value_loss           | 3.32        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 233          |
# |    ep_rew_mean          | 233          |
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 15           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0073840516 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.517       |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.421        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 3.14         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 16          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008764181 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.192       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00476    |
# |    value_loss           | 1.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 269         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 361         |
# |    iterations           | 17          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008128359 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0186      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000816   |
# |    value_loss           | 0.781       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 288          |
# |    ep_rew_mean          | 288          |
# | time/                   |              |
# |    fps                  | 365          |
# |    iterations           | 18           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0017136035 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.0472       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0283       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000333    |
# |    value_loss           | 0.509        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 305          |
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 19           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0046900646 |
# |    clip_fraction        | 0.0467       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.0918       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0561       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00336     |
# |    value_loss           | 0.325        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | 323          |
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 20           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0011205497 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.0352       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.028        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000358    |
# |    value_loss           | 0.191        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 339         |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 21          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.004816804 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | 0.0187      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 0.129       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 356          |
# |    ep_rew_mean          | 356          |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 22           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0013279082 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.0399       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0264       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000263    |
# |    value_loss           | 0.0737       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 373         |
# |    ep_rew_mean          | 373         |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 23          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003708774 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.0301      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00158    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 0.0499      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 393         |
# |    ep_rew_mean          | 393         |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 24          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006926423 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.0036      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00817     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 409          |
# |    ep_rew_mean          | 409          |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 25           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0019269164 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0.0302       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000904    |
# |    value_loss           | 0.0209       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 420          |
# |    ep_rew_mean          | 420          |
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 26           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0026244472 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.468       |
# |    explained_variance   | 0.0101       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.012        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 434          |
# |    ep_rew_mean          | 434          |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 27           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0021520918 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0.0625       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00143      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000474    |
# |    value_loss           | 0.0082       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 446          |
# |    ep_rew_mean          | 446          |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 28           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0041055945 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.0188       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00188      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.00536      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 457          |
# |    ep_rew_mean          | 457          |
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 29           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0043116603 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000303     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 0.00373      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 468          |
# |    ep_rew_mean          | 468          |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 30           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0035889423 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.0226       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0131       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000942    |
# |    value_loss           | 0.0024       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 475          |
# |    ep_rew_mean          | 475          |
# | time/                   |              |
# |    fps                  | 395          |
# |    iterations           | 31           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0047061527 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | -0.034       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0148      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 0.00162      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 485          |
# |    ep_rew_mean          | 485          |
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 32           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0023811373 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.493       |
# |    explained_variance   | 0.018        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0109       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 0.00113      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 491          |
# |    ep_rew_mean          | 491          |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 33           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0017784485 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.509       |
# |    explained_variance   | -0.142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0363       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000317    |
# |    value_loss           | 0.000769     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 497          |
# |    ep_rew_mean          | 497          |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 34           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0023147683 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | -0.0864      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00848     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 0.000525     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 35          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005297565 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.488      |
# |    explained_variance   | -0.0163     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 0.000383    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 36           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0040248632 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0195      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 0.000259     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 37          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003471586 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.483      |
# |    explained_variance   | -0.0645     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00765    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 0.000185    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 38          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.002709301 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | -0.131      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00437     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000322   |
# |    value_loss           | 0.00013     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 39           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0027102157 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | -0.0929      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000107     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000748    |
# |    value_loss           | 9.46e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 40          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002908139 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | -0.166      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00706    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 6.58e-05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 41           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0034027444 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | -0.129       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0153       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 4.8e-05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 42           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0030345141 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | -0.188       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00105     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 3.53e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 43           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0033198397 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | -0.189       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0111      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 2.34e-05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 44          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004375483 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | -0.322      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00356    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 1.98e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 45          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.002550124 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.423      |
# |    explained_variance   | -0.228      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00597     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -9.7e-05    |
# |    value_loss           | 1.3e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 46          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005796693 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.0293      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00332    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 8.93e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 47           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0021653469 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.377       |
# |    explained_variance   | -0.0816      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00315      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 7.45e-06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 48          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008133484 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | -0.359      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00202     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00507    |
# |    value_loss           | 5.48e-06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 49           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0019882917 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.376       |
# |    explained_variance   | -0.323       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000335    |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000541    |
# |    value_loss           | 3.92e-06     |
# ------------------------------------------
# /home/intifada/Documents/rcp211/.venv/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# === Évaluation de l'expert PPO ===
# Score moyen : 500.00 ± 0.00

# %% [markdown]
# ### Collecte des démonstrations

# %%
# =========================
# 2. Collecte des démonstrations expertes
# =========================

demo_env = gym.make(ENV_NAME)

trajectories = []

episode_id = 0

while len(trajectories) < N_DEMO_EPISODES:
    obs, info = demo_env.reset(seed=SEED + episode_id)

    states = []
    actions = []
    rewards = []
    next_states = []
    dones = []

    done = False
    truncated = False
    episode_reward = 0

    while not (done or truncated):
        action, _ = model.predict(obs, deterministic=True)

        next_obs, reward, done, truncated, info = demo_env.step(action)

        states.append(obs)
        actions.append(action)
        rewards.append(reward)
        next_states.append(next_obs)
        dones.append(done or truncated)

        obs = next_obs
        episode_reward += reward

    if episode_reward >= MIN_EXPERT_SCORE:
        trajectory = {
            "states": np.array(states, dtype=np.float32),
            "actions": np.array(actions, dtype=np.int64),
            "rewards": np.array(rewards, dtype=np.float32),
            "next_states": np.array(next_states, dtype=np.float32),
            "dones": np.array(dones, dtype=bool),
            "episode_reward": episode_reward,
        }

        trajectories.append(trajectory)

        print(
            f"Trajectoire retenue {len(trajectories)}/{N_DEMO_EPISODES} "
            f"- score = {episode_reward}"
        )
    else:
        print(f"Trajectoire rejetée - score = {episode_reward}")

    episode_id += 1
# Out:
# Trajectoire retenue 1/50 - score = 500.0
# Trajectoire retenue 2/50 - score = 500.0
# Trajectoire retenue 3/50 - score = 500.0
# Trajectoire retenue 4/50 - score = 500.0
# Trajectoire retenue 5/50 - score = 500.0
# Trajectoire retenue 6/50 - score = 500.0
# Trajectoire retenue 7/50 - score = 500.0
# Trajectoire retenue 8/50 - score = 500.0
# Trajectoire retenue 9/50 - score = 500.0
# Trajectoire retenue 10/50 - score = 500.0
# Trajectoire retenue 11/50 - score = 500.0
# Trajectoire retenue 12/50 - score = 500.0
# Trajectoire retenue 13/50 - score = 500.0
# Trajectoire retenue 14/50 - score = 500.0
# Trajectoire retenue 15/50 - score = 500.0
# Trajectoire retenue 16/50 - score = 500.0
# Trajectoire retenue 17/50 - score = 500.0
# Trajectoire retenue 18/50 - score = 500.0
# Trajectoire retenue 19/50 - score = 500.0
# Trajectoire retenue 20/50 - score = 500.0
# Trajectoire retenue 21/50 - score = 500.0
# Trajectoire retenue 22/50 - score = 500.0
# Trajectoire retenue 23/50 - score = 500.0
# Trajectoire retenue 24/50 - score = 500.0
# Trajectoire retenue 25/50 - score = 500.0
# Trajectoire retenue 26/50 - score = 500.0
# Trajectoire retenue 27/50 - score = 500.0
# Trajectoire retenue 28/50 - score = 500.0
# Trajectoire retenue 29/50 - score = 500.0
# Trajectoire retenue 30/50 - score = 500.0
# Trajectoire retenue 31/50 - score = 500.0
# Trajectoire retenue 32/50 - score = 500.0
# Trajectoire retenue 33/50 - score = 500.0
# Trajectoire retenue 34/50 - score = 500.0
# Trajectoire retenue 35/50 - score = 500.0
# Trajectoire retenue 36/50 - score = 500.0
# Trajectoire retenue 37/50 - score = 500.0
# Trajectoire retenue 38/50 - score = 500.0
# Trajectoire retenue 39/50 - score = 500.0
# Trajectoire retenue 40/50 - score = 500.0
# Trajectoire retenue 41/50 - score = 500.0
# Trajectoire retenue 42/50 - score = 500.0
# Trajectoire retenue 43/50 - score = 500.0
# Trajectoire retenue 44/50 - score = 500.0
# Trajectoire retenue 45/50 - score = 500.0
# Trajectoire retenue 46/50 - score = 500.0
# Trajectoire retenue 47/50 - score = 500.0
# Trajectoire retenue 48/50 - score = 500.0
# Trajectoire retenue 49/50 - score = 500.0
# Trajectoire retenue 50/50 - score = 500.0

# %% [markdown]
# ### Construction du dataset

# %%
# =========================
# 3. Construction d'un dataset aplati
# =========================

all_states = np.concatenate([traj["states"] for traj in trajectories], axis=0)
all_actions = np.concatenate([traj["actions"] for traj in trajectories], axis=0)
all_rewards = np.concatenate([traj["rewards"] for traj in trajectories], axis=0)
all_next_states = np.concatenate([traj["next_states"] for traj in trajectories], axis=0)
all_dones = np.concatenate([traj["dones"] for traj in trajectories], axis=0)

episode_rewards = np.array(
    [traj["episode_reward"] for traj in trajectories],
    dtype=np.float32,
)

# %% [markdown]
# ### Sauvegarde

# %%
# =========================
# 4. Sauvegarde
# =========================

np.savez(
    DEMO_DATA_PATH,
    states=all_states,
    actions=all_actions,
    rewards=all_rewards,
    next_states=all_next_states,
    dones=all_dones,
    episode_rewards=episode_rewards,
)

print("\n=== Dataset de démonstrations sauvegardé ===")
print(f"Chemin : {DEMO_DATA_PATH}")
print(f"Nombre de trajectoires : {len(trajectories)}")
print(f"Nombre total de transitions : {len(all_states)}")
print(f"Dimension des états : {all_states.shape}")
print(f"Dimension des actions : {all_actions.shape}")
print(f"Score moyen des démonstrations : {episode_rewards.mean():.2f}")
# Out:
# === Dataset de démonstrations sauvegardé ===
# Chemin : /home/intifada/Documents/rcp211/04_Projet/data/expert_demonstrations.npz
# Nombre de trajectoires : 50
# Nombre total de transitions : 25000
# Dimension des états : (25000, 4)
# Dimension des actions : (25000,)
# Score moyen des démonstrations : 500.00

# %% [markdown]
# ## Construction du modèle de reward

# %% [markdown]
# ### Environement & Librairies

# %%
import os
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler

N_RANDOM_EPISODES = 100
N_EPOCHS = 100
BATCH_SIZE = 256
LR = 1e-3
SEED = 42

os.makedirs(MODEL_DIR, exist_ok=True)

# %% [markdown]
# ### Modèles de rewards

# %%
# ============================================================
# 1. Modèles de reward
# ============================================================

class LinearReward(nn.Module):
    """
    Reward linéaire :
    r(s) = w^T s + b
    """

    def __init__(self, state_dim):
        super().__init__()
        self.linear = nn.Linear(state_dim, 1)

    def forward(self, state):
        return self.linear(state)


class QuadraticReward(nn.Module):
    """
    Reward quadratique :
    r(s) = w^T [s, s^2] + b

    On enrichit les features avec les carrés des variables.
    """

    def __init__(self, state_dim):
        super().__init__()
        self.linear = nn.Linear(2 * state_dim, 1)

    def forward(self, state):
        features = torch.cat([state, state ** 2], dim=1)
        return self.linear(features)


class NeuralReward(nn.Module):
    """
    Reward non linéaire par réseau de neurones.
    """

    def __init__(self, state_dim):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(state_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, state):
        return self.net(state)

# %% [markdown]
# ### Classe d'entrainement

# %%
# ============================================================
# 2. Classe d'entraînement commune
# ============================================================

class RewardTrainer:
    def __init__(
        self,
        demo_data_path,
        n_random_episodes=1000,
        batch_size=256,
        lr=1e-3,
        n_epochs=100,
        seed=42,
    ):
        self.demo_data_path = demo_data_path
        self.n_random_episodes = n_random_episodes
        self.batch_size = batch_size
        self.lr = lr
        self.n_epochs = n_epochs
        self.seed = seed

        self.scaler = StandardScaler()

        self.X_tensor = None
        self.y_tensor = None
        self.expert_states = None
        self.random_states = None

    def load_expert_states(self):
        data = np.load(self.demo_data_path)
        self.expert_states = data["states"].astype(np.float32)

        print("États experts :", self.expert_states.shape)

    def generate_random_states(self):
        env = gym.make(ENV_NAME)

        random_states = []

        for episode in range(self.n_random_episodes):
            obs, info = env.reset(seed=self.seed + episode)
            done = False
            truncated = False

            while not (done or truncated):
                action = env.action_space.sample()
                next_obs, reward, done, truncated, info = env.step(action)

                random_states.append(obs)
                obs = next_obs

        self.random_states = np.array(random_states, dtype=np.float32)

        print("États random :", self.random_states.shape)

    def build_dataset(self):
        n = min(len(self.expert_states), len(self.random_states))

        self.expert_states = self.expert_states[:n]
        self.random_states = self.random_states[:n]

        X = np.concatenate([self.expert_states, self.random_states], axis=0)

        y_expert = np.ones((n, 1), dtype=np.float32)
        y_random = np.zeros((n, 1), dtype=np.float32)
        y = np.concatenate([y_expert, y_random], axis=0)

        rng = np.random.default_rng(self.seed)
        indices = rng.permutation(len(X))

        X = X[indices]
        y = y[indices]

        X_scaled = self.scaler.fit_transform(X).astype(np.float32)

        self.X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        self.y_tensor = torch.tensor(y, dtype=torch.float32)

    def prepare_data(self):
        self.load_expert_states()
        self.generate_random_states()
        self.build_dataset()

    def train_model(self, model, model_name):
        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=self.lr)

        dataset_size = len(self.X_tensor)

        for epoch in range(self.n_epochs):
            permutation = torch.randperm(dataset_size)

            epoch_loss = 0.0

            for i in range(0, dataset_size, self.batch_size):
                batch_idx = permutation[i:i + self.batch_size]

                batch_X = self.X_tensor[batch_idx]
                batch_y = self.y_tensor[batch_idx]

                logits = model(batch_X)
                loss = criterion(logits, batch_y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                epoch_loss += loss.item()

            if (epoch + 1) % 10 == 0:
                print(
                    f"{model_name} | Epoch {epoch + 1}/{self.n_epochs} "
                    f"- Loss : {epoch_loss:.4f}"
                )

        return model

    def evaluate_model(self, model, model_name):
        with torch.no_grad():
            expert_scaled = self.scaler.transform(self.expert_states).astype(np.float32)
            random_scaled = self.scaler.transform(self.random_states).astype(np.float32)

            expert_tensor = torch.tensor(expert_scaled, dtype=torch.float32)
            random_tensor = torch.tensor(random_scaled, dtype=torch.float32)

            expert_scores = model(expert_tensor).numpy()
            random_scores = model(random_tensor).numpy()

        print(f"\n=== Évaluation {model_name} ===")
        print(f"Score moyen expert : {expert_scores.mean():.4f}")
        print(f"Score moyen random  : {random_scores.mean():.4f}")

    def save_model(self, model, model_name):
        model_path = os.path.join(MODEL_DIR, f"{model_name}.pth")
        scaler_path = os.path.join(MODEL_DIR, f"{model_name}_scaler.npz")

        torch.save(model.state_dict(), model_path)

        np.savez(
            scaler_path,
            mean=self.scaler.mean_,
            scale=self.scaler.scale_,
        )

        print(f"\nModèle sauvegardé : {model_path}")
        print(f"Scaler sauvegardé : {scaler_path}")

    def train_and_save(self, model, model_name):
        print(f"\n==============================")
        print(f"Entraînement du modèle : {model_name}")
        print(f"==============================")

        model = self.train_model(model, model_name)
        self.evaluate_model(model, model_name)
        self.save_model(model, model_name)

        return model

# %% [markdown]
# ### Apprentissage des différentes rewards

# %%
# ============================================================
# 3. Exécution
# ============================================================

if __name__ == "__main__":
    trainer = RewardTrainer(
        demo_data_path=DEMO_DATA_PATH,
        n_random_episodes=N_RANDOM_EPISODES,
        batch_size=BATCH_SIZE,
        lr=LR,
        n_epochs=N_EPOCHS,
        seed=SEED,
    )

    trainer.prepare_data()

    state_dim = trainer.X_tensor.shape[1]

    models = {
        "linear_reward": LinearReward(state_dim),
        "quadratic_reward": QuadraticReward(state_dim),
        "neural_reward": NeuralReward(state_dim),
    }

    trained_models = {}

    for model_name, model in models.items():
        trained_models[model_name] = trainer.train_and_save(model, model_name)
# Out:
# États experts : (25000, 4)
# États random : (2305, 4)
#
# ==============================
# Entraînement du modèle : linear_reward
# ==============================
# linear_reward | Epoch 10/100 - Loss : 14.5190
# linear_reward | Epoch 20/100 - Loss : 13.2174
# linear_reward | Epoch 30/100 - Loss : 12.0782
# linear_reward | Epoch 40/100 - Loss : 11.0123
# linear_reward | Epoch 50/100 - Loss : 10.2139
# linear_reward | Epoch 60/100 - Loss : 9.8029
# linear_reward | Epoch 70/100 - Loss : 9.0637
# linear_reward | Epoch 80/100 - Loss : 8.5551
# linear_reward | Epoch 90/100 - Loss : 8.1581
# linear_reward | Epoch 100/100 - Loss : 7.7533
#
# === Évaluation linear_reward ===
# Score moyen expert : 0.8486
# Score moyen random  : -0.8094
#
# Modèle sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/linear_reward.pth
# Scaler sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/linear_reward_scaler.npz
#
# ==============================
# Entraînement du modèle : quadratic_reward
# ==============================
# quadratic_reward | Epoch 10/100 - Loss : 9.6659
# quadratic_reward | Epoch 20/100 - Loss : 8.1571
# quadratic_reward | Epoch 30/100 - Loss : 7.1366
# quadratic_reward | Epoch 40/100 - Loss : 6.1305
# quadratic_reward | Epoch 50/100 - Loss : 5.4471
# quadratic_reward | Epoch 60/100 - Loss : 5.3337
# quadratic_reward | Epoch 70/100 - Loss : 4.8584
# quadratic_reward | Epoch 80/100 - Loss : 4.7580
# quadratic_reward | Epoch 90/100 - Loss : 4.2182
# quadratic_reward | Epoch 100/100 - Loss : 4.2094
#
# === Évaluation quadratic_reward ===
# Score moyen expert : 1.8409
# Score moyen random  : -4.1535
#
# Modèle sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/quadratic_reward.pth
# Scaler sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/quadratic_reward_scaler.npz
#
# ==============================
# Entraînement du modèle : neural_reward
# ==============================
# neural_reward | Epoch 10/100 - Loss : 3.3365
# neural_reward | Epoch 20/100 - Loss : 2.3089
# neural_reward | Epoch 30/100 - Loss : 2.2022
# neural_reward | Epoch 40/100 - Loss : 1.8638
# neural_reward | Epoch 50/100 - Loss : 1.7769
# neural_reward | Epoch 60/100 - Loss : 1.9477
# neural_reward | Epoch 70/100 - Loss : 2.2275
# neural_reward | Epoch 80/100 - Loss : 1.5689
# neural_reward | Epoch 90/100 - Loss : 1.5630
# neural_reward | Epoch 100/100 - Loss : 1.5048
#
# === Évaluation neural_reward ===
# Score moyen expert : 8.2575
# Score moyen random  : -13.7287
#
# Modèle sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/neural_reward.pth
# Scaler sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/neural_reward_scaler.npz

# %% [markdown]
# ## Utilisation des rewards apprises

# %% [markdown]
# ### Librairies & dossiers de résultats

# %%
import os
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy


RESULTS_DIR = os.path.join(ROOT_DIR, "results")
os.makedirs(RESULTS_DIR, exist_ok=True)

N_TRAINING_STEPS = 100_000
N_EVAL_EPISODES = 20
SEED = 42

# %% [markdown]
# ### Création du modèle de RL

# %%
class LearnedRewardWrapper(gym.Wrapper):
    def __init__(self, env, reward_model, scaler_mean, scaler_scale):
        super().__init__(env)

        self.reward_model = reward_model
        self.reward_model.eval()

        self.scaler_mean = scaler_mean.astype(np.float32)
        self.scaler_scale = scaler_scale.astype(np.float32)

    def step(self, action):
        obs, true_reward, terminated, truncated, info = self.env.step(action)

        obs_scaled = (obs.astype(np.float32) - self.scaler_mean) / self.scaler_scale
        obs_tensor = torch.tensor(obs_scaled, dtype=torch.float32).unsqueeze(0)

        with torch.no_grad():
            learned_reward = self.reward_model(obs_tensor).item()

        info["true_reward"] = true_reward
        info["learned_reward"] = learned_reward

        return obs, learned_reward, terminated, truncated, info

# %% [markdown]
# ### Chargement d'une reward

# %%
# ============================================================
# 3. Chargement d'une reward apprise
# ============================================================

def load_reward_model(model_name, model_class, state_dim=4):
    model_path = os.path.join(MODEL_DIR, f"{model_name}.pth")
    scaler_path = os.path.join(MODEL_DIR, f"{model_name}_scaler.npz")

    model = model_class(state_dim)
    model.load_state_dict(torch.load(model_path, map_location="cpu"))
    model.eval()

    scaler_data = np.load(scaler_path)
    scaler_mean = scaler_data["mean"]
    scaler_scale = scaler_data["scale"]

    return model, scaler_mean, scaler_scale


def make_learned_reward_env(model_name, model_class):
    base_env = gym.make(ENV_NAME)

    reward_model, scaler_mean, scaler_scale = load_reward_model(
        model_name=model_name,
        model_class=model_class,
        state_dim=4,
    )

    env = LearnedRewardWrapper(
        env=base_env,
        reward_model=reward_model,
        scaler_mean=scaler_mean,
        scaler_scale=scaler_scale,
    )

    return env

# %% [markdown]
# ### Entrainement avec une reward

# %%
# ============================================================
# 4. Entraînement PPO avec reward apprise
# ============================================================

def train_agent_with_reward(model_name, model_class):
    print("\n============================================")
    print(f"Entraînement PPO avec reward : {model_name}")
    print("============================================")

    train_env = make_learned_reward_env(model_name, model_class)

    model = PPO(
        policy="MlpPolicy",
        env=train_env,
        verbose=1,
        seed=SEED,
    )

    model.learn(total_timesteps=N_TRAINING_STEPS)

    agent_path = os.path.join(MODEL_DIR, f"ppo_with_{model_name}")
    model.save(agent_path)

    print(f"Agent sauvegardé : {agent_path}")

    return model

# %% [markdown]
# ### Evaluation

# %%
# ============================================================
# 5. Évaluation sur la vraie reward CartPole
# ============================================================

def evaluate_on_true_reward(model, model_name):
    eval_env = gym.make(ENV_NAME)

    mean_reward, std_reward = evaluate_policy(
        model,
        eval_env,
        n_eval_episodes=N_EVAL_EPISODES,
        deterministic=True,
    )

    print("\n=== Évaluation vraie reward CartPole ===")
    print(f"Reward utilisée à l'entraînement : {model_name}")
    print(f"Score moyen réel : {mean_reward:.2f} ± {std_reward:.2f}")

    return mean_reward, std_reward

# %% [markdown]
# ### Execution finale

# %%
# ============================================================
# 6. Exécution complète
# ============================================================

if __name__ == "__main__":

    reward_models = {
        "linear_reward": LinearReward,
        "quadratic_reward": QuadraticReward,
        "neural_reward": NeuralReward,
    }

    results = []

    for model_name, model_class in reward_models.items():
        ppo_model = train_agent_with_reward(model_name, model_class)
        mean_reward, std_reward = evaluate_on_true_reward(ppo_model, model_name)

        results.append((model_name, mean_reward, std_reward))

    print("\n============================================")
    print("Résumé final")
    print("============================================")

    for model_name, mean_reward, std_reward in results:
        print(f"{model_name:20s} : {mean_reward:.2f} ± {std_reward:.2f}")

    results_path = os.path.join(RESULTS_DIR, "learned_reward_results.csv")

    with open(results_path, "w") as f:
        f.write("model_name,mean_true_reward,std_true_reward\n")
        for model_name, mean_reward, std_reward in results:
            f.write(f"{model_name},{mean_reward},{std_reward}\n")

    print(f"\nRésultats sauvegardés : {results_path}")
# Out:
# ============================================
# Entraînement PPO avec reward : linear_reward
# ============================================
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -20.6    |
# | time/              |          |
# |    fps             | 632      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.7         |
# |    ep_rew_mean          | -18.2        |
# | time/                   |              |
# |    fps                  | 455          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0062191365 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.00158      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26           |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00683     |
# |    value_loss           | 79.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 15.6       |
# |    ep_rew_mean          | -11.5      |
# | time/                   |            |
# |    fps                  | 375        |
# |    iterations           | 3          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01857106 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.642     |
# |    explained_variance   | 0.189      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68.2       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0225    |
# |    value_loss           | 106        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.8        |
# |    ep_rew_mean          | -7.91       |
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.027296364 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.6        |
# |    ep_rew_mean          | -6.24       |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.030750869 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 3.2         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | -5.6       |
# | time/                   |            |
# |    fps                  | 354        |
# |    iterations           | 6          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02251836 |
# |    clip_fraction        | 0.0813     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.322     |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0677     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0255    |
# |    value_loss           | 0.641      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.71         |
# |    ep_rew_mean          | -5.37        |
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 7            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0049886657 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0498       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 0.18         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.52         |
# |    ep_rew_mean          | -5.75        |
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 8            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0025018845 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0331       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00944     |
# |    value_loss           | 0.0896       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.62         |
# |    ep_rew_mean          | -5.82        |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 9            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0022538882 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.164       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0373       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00966     |
# |    value_loss           | 0.0661       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.5          |
# |    ep_rew_mean          | -5.59        |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 10           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0020264643 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.147       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0127       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 0.0475       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.41        |
# |    ep_rew_mean          | -5.67       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 11          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002072043 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.16       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00581     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 0.0424      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.48         |
# |    ep_rew_mean          | -5.59        |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 12           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0011480848 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.139       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0146       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 0.0225       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.44        |
# |    ep_rew_mean          | -5.05       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 13          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002934722 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.115      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00614    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 0.0258      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.23       |
# |    ep_rew_mean          | -5.72      |
# | time/                   |            |
# |    fps                  | 339        |
# |    iterations           | 14         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.00200107 |
# |    clip_fraction        | 0.0177     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.101     |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00639    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0022    |
# |    value_loss           | 0.0248     |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.38          |
# |    ep_rew_mean          | -5.65         |
# | time/                   |               |
# |    fps                  | 339           |
# |    iterations           | 15            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00032451178 |
# |    clip_fraction        | 0.00898       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0924       |
# |    explained_variance   | 0.996         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00225       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 0.0208        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.44          |
# |    ep_rew_mean          | -5.76         |
# | time/                   |               |
# |    fps                  | 342           |
# |    iterations           | 16            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00090836454 |
# |    clip_fraction        | 0.0135        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.106        |
# |    explained_variance   | 0.996         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00777       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000166     |
# |    value_loss           | 0.0211        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.43        |
# |    ep_rew_mean          | -5.75       |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 17          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.000891523 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0771     |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00445    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000885   |
# |    value_loss           | 0.0162      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.49         |
# |    ep_rew_mean          | -5.33        |
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 18           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0011570572 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0869      |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00666     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000583    |
# |    value_loss           | 0.0132       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.43         |
# |    ep_rew_mean          | -5.06        |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 19           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0015252288 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0793      |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00133     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000865    |
# |    value_loss           | 0.0175       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.4         |
# |    ep_rew_mean          | -5.36       |
# | time/                   |             |
# |    fps                  | 338         |
# |    iterations           | 20          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.000770341 |
# |    clip_fraction        | 0.0101      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0804     |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00794     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000421    |
# |    value_loss           | 0.0152      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.34          |
# |    ep_rew_mean          | -5.16         |
# | time/                   |               |
# |    fps                  | 337           |
# |    iterations           | 21            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00052315765 |
# |    clip_fraction        | 0.0062        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0721       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00233       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 0.000314      |
# |    value_loss           | 0.0127        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.43         |
# |    ep_rew_mean          | -5.24        |
# | time/                   |              |
# |    fps                  | 338          |
# |    iterations           | 22           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0009758789 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.072       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000837    |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000116    |
# |    value_loss           | 0.0122       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.4         |
# |    ep_rew_mean          | -5.37       |
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 23          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.000448298 |
# |    clip_fraction        | 0.00771     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0676     |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0038      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000248    |
# |    value_loss           | 0.0119      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.37         |
# |    ep_rew_mean          | -5.33        |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 24           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0008075209 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0546      |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00413      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.000159     |
# |    value_loss           | 0.00961      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.36          |
# |    ep_rew_mean          | -5.46         |
# | time/                   |               |
# |    fps                  | 336           |
# |    iterations           | 25            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00057676074 |
# |    clip_fraction        | 0.00854       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0589       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00485       |
# |    n_updates            | 240           |
# |    policy_gradient_loss | 0.000917      |
# |    value_loss           | 0.0101        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.42         |
# |    ep_rew_mean          | -5.32        |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 26           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0003004822 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0573      |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.000408     |
# |    value_loss           | 0.00955      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.33          |
# |    ep_rew_mean          | -5.39         |
# | time/                   |               |
# |    fps                  | 321           |
# |    iterations           | 27            |
# |    time_elapsed         | 172           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00066181377 |
# |    clip_fraction        | 0.00957       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0518       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00818       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 0.000229      |
# |    value_loss           | 0.0124        |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.33       |
# |    ep_rew_mean          | -5.6       |
# | time/                   |            |
# |    fps                  | 317        |
# |    iterations           | 28         |
# |    time_elapsed         | 180        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.00174853 |
# |    clip_fraction        | 0.00742    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0406    |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00772    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | 0.000799   |
# |    value_loss           | 0.0114     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.25        |
# |    ep_rew_mean          | -5.64       |
# | time/                   |             |
# |    fps                  | 315         |
# |    iterations           | 29          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.001778916 |
# |    clip_fraction        | 0.00752     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0365     |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0033      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.000756    |
# |    value_loss           | 0.00833     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.39          |
# |    ep_rew_mean          | -5.44         |
# | time/                   |               |
# |    fps                  | 315           |
# |    iterations           | 30            |
# |    time_elapsed         | 194           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00076953694 |
# |    clip_fraction        | 0.0109        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0453       |
# |    explained_variance   | 0.999         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00502       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 0.000828      |
# |    value_loss           | 0.00736       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.32         |
# |    ep_rew_mean          | -5.35        |
# | time/                   |              |
# |    fps                  | 314          |
# |    iterations           | 31           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 7.512828e-05 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0355      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0038       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000851     |
# |    value_loss           | 0.00813      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.28         |
# |    ep_rew_mean          | -5.28        |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 32           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 5.356685e-05 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0315      |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00675      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 3.12e-05     |
# |    value_loss           | 0.00818      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.39          |
# |    ep_rew_mean          | -5.42         |
# | time/                   |               |
# |    fps                  | 314           |
# |    iterations           | 33            |
# |    time_elapsed         | 214           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00032615714 |
# |    clip_fraction        | 0.00806       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0381       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00503       |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 0.00114       |
# |    value_loss           | 0.00941       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.43         |
# |    ep_rew_mean          | -5.45        |
# | time/                   |              |
# |    fps                  | 315          |
# |    iterations           | 34           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0018836082 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0555      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00149     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000749     |
# |    value_loss           | 0.00699      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.24          |
# |    ep_rew_mean          | -5.65         |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 35            |
# |    time_elapsed         | 225           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00025983359 |
# |    clip_fraction        | 0.00454       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0388       |
# |    explained_variance   | 0.999         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000847      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.000985      |
# |    value_loss           | 0.00696       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.51         |
# |    ep_rew_mean          | -5.13        |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 36           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0004105763 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0441      |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00564      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000126     |
# |    value_loss           | 0.00811      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.41         |
# |    ep_rew_mean          | -5.23        |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 37           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0020350702 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0532      |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00353      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000971     |
# |    value_loss           | 0.00916      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.38          |
# |    ep_rew_mean          | -5.4          |
# | time/                   |               |
# |    fps                  | 322           |
# |    iterations           | 38            |
# |    time_elapsed         | 241           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00097411626 |
# |    clip_fraction        | 0.0118        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0583       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00071       |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 0.00045       |
# |    value_loss           | 0.00857       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.37         |
# |    ep_rew_mean          | -5.58        |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 39           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0016110132 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0633      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00573      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 2.51e-05     |
# |    value_loss           | 0.00713      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.25         |
# |    ep_rew_mean          | -5.8         |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 40           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0005413972 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0669      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00561      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00103      |
# |    value_loss           | 0.00724      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.32          |
# |    ep_rew_mean          | -5.77         |
# | time/                   |               |
# |    fps                  | 326           |
# |    iterations           | 41            |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00018284758 |
# |    clip_fraction        | 0.0123        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0633       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00448       |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0.00097       |
# |    value_loss           | 0.00892       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.2          |
# |    ep_rew_mean          | -5.82        |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 42           |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0008067038 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0602      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00221     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000493     |
# |    value_loss           | 0.00831      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.55          |
# |    ep_rew_mean          | -5.5          |
# | time/                   |               |
# |    fps                  | 330           |
# |    iterations           | 43            |
# |    time_elapsed         | 266           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00040339603 |
# |    clip_fraction        | 0.0113        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0525       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000465     |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 3.28e-05      |
# |    value_loss           | 0.00861       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.28         |
# |    ep_rew_mean          | -5.25        |
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 44           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0007740429 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0689      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00983      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000324    |
# |    value_loss           | 0.00839      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.43         |
# |    ep_rew_mean          | -5.65        |
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 45           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0007613457 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0623      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00703      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.000606     |
# |    value_loss           | 0.00707      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.34          |
# |    ep_rew_mean          | -5.41         |
# | time/                   |               |
# |    fps                  | 333           |
# |    iterations           | 46            |
# |    time_elapsed         | 282           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00047898732 |
# |    clip_fraction        | 0.00859       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0563       |
# |    explained_variance   | 0.998         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0059        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 0.000464      |
# |    value_loss           | 0.00943       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.46        |
# |    ep_rew_mean          | -5.35       |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 47          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.001101092 |
# |    clip_fraction        | 0.0154      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0665     |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000639   |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000255   |
# |    value_loss           | 0.00723     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.39         |
# |    ep_rew_mean          | -5.52        |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 48           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0008145837 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0749      |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00255      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -4.44e-05    |
# |    value_loss           | 0.00804      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.3         |
# |    ep_rew_mean          | -5.51       |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 49          |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.001793476 |
# |    clip_fraction        | 0.00737     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0708     |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0065     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000294   |
# |    value_loss           | 0.00752     |
# -----------------------------------------
# Agent sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/ppo_with_linear_reward
#
# === Évaluation vraie reward CartPole ===
# Reward utilisée à l'entraînement : linear_reward
# Score moyen réel : 9.15 ± 0.96
#
# ============================================
# Entraînement PPO avec reward : quadratic_reward
# ============================================
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/intifada/Documents/rcp211/.venv/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    fps             | 621      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010476714 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.000892    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 985         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 2.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | -121        |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009326388 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 494         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.65e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33           |
# |    ep_rew_mean          | -120         |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 4            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0038831513 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.661       |
# |    explained_variance   | -0.00026     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 543          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.8        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# ...
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 3.69e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12.6         |
# |    ep_rew_mean          | -248         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 33           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0030037868 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | -4.05e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.54e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 3.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 12           |
# |    ep_rew_mean          | -241         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 34           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0025302847 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.000232     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 3.97e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.2       |
# |    ep_rew_mean          | -236       |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 35         |
# |    time_elapsed         | 178        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02407061 |
# |    clip_fraction        | 0.0851     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.394     |
# |    explained_variance   | -2.01e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.53e+03   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0047    |
# |    value_loss           | 3.45e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.6         |
# |    ep_rew_mean          | -233         |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 36           |
# |    time_elapsed         | 184          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0017464397 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.33        |
# |    explained_variance   | 0.00292      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 3.24e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 11.7          |
# |    ep_rew_mean          | -237          |
# | time/                   |               |
# |    fps                  | 399           |
# |    iterations           | 37            |
# |    time_elapsed         | 189           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00096783554 |
# |    clip_fraction        | 0.00444       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.345        |
# |    explained_variance   | -2.15e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+03      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000539     |
# |    value_loss           | 3.13e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.9         |
# |    ep_rew_mean          | -234         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 38           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0011160417 |
# |    clip_fraction        | 0.00488      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | -4.17e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000742    |
# |    value_loss           | 3.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.1         |
# |    ep_rew_mean          | -237         |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 39           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0038028378 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.312       |
# |    explained_variance   | -1.07e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 3.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | -236        |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 40          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002471354 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | -5.84e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000262   |
# |    value_loss           | 3.09e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.4         |
# |    ep_rew_mean          | -233         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 41           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0017786347 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.222       |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 3.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.3         |
# |    ep_rew_mean          | -231         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 42           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0019788563 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | -2.26e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000349     |
# |    value_loss           | 3e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.6         |
# |    ep_rew_mean          | -232         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 43           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011137133 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.203       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000813    |
# |    value_loss           | 2.92e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10.7          |
# |    ep_rew_mean          | -235          |
# | time/                   |               |
# |    fps                  | 399           |
# |    iterations           | 44            |
# |    time_elapsed         | 225           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00091233884 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.2          |
# |    explained_variance   | -1.31e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.67e+03      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -1.76e-05     |
# |    value_loss           | 2.94e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.5         |
# |    ep_rew_mean          | -236         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 45           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0014456603 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 9.71e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000825    |
# |    value_loss           | 3.06e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.92       |
# |    ep_rew_mean          | -232       |
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 46         |
# |    time_elapsed         | 235        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00064421 |
# |    clip_fraction        | 0.0102     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.15      |
# |    explained_variance   | -9.89e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 870        |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.000575  |
# |    value_loss           | 3.05e+03   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 9.68          |
# |    ep_rew_mean          | -227          |
# | time/                   |               |
# |    fps                  | 400           |
# |    iterations           | 47            |
# |    time_elapsed         | 240           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00066585565 |
# |    clip_fraction        | 0.00229       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.143        |
# |    explained_variance   | -0.00195      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.44e+03      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | 8.64e-05      |
# |    value_loss           | 3.05e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.4         |
# |    ep_rew_mean          | -234         |
# | time/                   |              |
# |    fps                  | 400          |
# |    iterations           | 48           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0031304404 |
# |    clip_fraction        | 0.00845      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.135       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00034     |
# |    value_loss           | 2.94e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.94         |
# |    ep_rew_mean          | -230         |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 49           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0011624566 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.00478      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.000239    |
# |    value_loss           | 3.02e+03     |
# ------------------------------------------
# Agent sauvegardé : /home/intifada/Documents/rcp211/4_Projet/models/ppo_with_neural_reward
#
# === Évaluation vraie reward CartPole ===
# Reward utilisée à l'entraînement : neural_reward
# Score moyen réel : 9.20 ± 0.75
#
# ============================================
# Résumé final
# ============================================
# linear_reward        : 9.15 ± 0.96
# quadratic_reward     : 34.60 ± 23.57
# neural_reward        : 9.20 ± 0.75
#
# Résultats sauvegardés : /home/intifada/Documents/rcp211/4_Projet/results/learned_reward_results.csv
